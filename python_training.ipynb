# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokulsudinan2005/coding-class/blob/main/python_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter total number of monkeys:"))
k=int(input("Enter number of banana monkey can eat:"))
j=int(input("Enter number of peanut monkey can eat:"))
m=int(input("Enter total number of banana:"))
p=int(input("Enter total number of peanut:"))
if(k==0 or j==0):
  print("INVALID INPUT")
else:
  n=n-(m//k+p//j)
  if(m%k!=0 or p%k!=0):
    n=n-1
  print("No. of monkeys in tree:",n)
# Out:
# Enter total number of monkeys:20
# Enter number of banana monkey can eat:2
# Enter number of peanut monkey can eat:3
# Enter total number of banana:12
# Enter total number of peanut:12
# No. of monkeys in tree: 10

# %%
print("using temp")
a=int(input("enter first number:a= "))
b=int(input("enter the second number:b= "))
temp=a
a=b
b=temp
print("after swapping: ")
print("a=",a)
print("b=",b)
# Out:
# using temp
# enter first number:a= 15
# enter the second number:b= 25
# after swapping:
# a= 25
# b= 15

# %%
print("using ,")
a=int(input("enter first number:a= "))
b=int(input("enter the second number:b= "))
a,b=b,a
print("after swapping: ")
print("a=",a)
print("b=",b)
# Out:
# using ,
# enter first number:a= 25
# enter the second number:b= 55
# after swapping:
# a= 55
# b= 25

# %%
print("using + & -")
a=int(input("enter first number:a= "))
b=int(input("enter the second number:b= "))
a=a+b
b=a-b
a=a-b
print("after swapping: ")
print("a=",a)
print("b=",b)
# Out:
# using + & -
# enter first number:a= 15
# enter the second number:b= 55
# after swapping:
# a= 55
# b= 15

# %%
print("using ^")
a=int(input("enter first number:a= "))
b=int(input("enter the second number:b= "))
a=a^b
b=a^b
a=a^b
print("after swapping: ")
print("a=",a)
print("b=",b)
# Out:
# using ^
# enter first number:a= 15
# enter the second number:b= 25
# after swapping:
# a= 25
# b= 15

# %%
n=10
k=5
candies =n
buy=int(input("wanted candies: "))
if buy>candies or buy<=0:
    print("INVALID INPUT")
else:
    candies=candies-buy

    print("number of candies sold: ",buy)
if candies <= k:
    candies = n
    print("number of available: ",candies)
# Out:
# wanted candies: 5
# number of candies sold:  5
# number of available:  10
